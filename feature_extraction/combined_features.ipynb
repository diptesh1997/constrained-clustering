# %%
import pandas as pd

# %%
word2vec=pd.read_csv("./Word2Vec.csv")
word2vec
# Out:
#                  docno         0         1         2         3         4  \
# 0       LA122989-0001   0.489329  0.441286  0.600067  0.512963  0.398550
# 1       LA122989-0002   0.501280  0.619327  0.500244  0.467507  0.446816
# 2       LA122989-0005   0.382171  0.541840  0.640981  0.435284  0.244308
# 3       LA122989-0006   0.550603  0.502243  0.392764  0.619229  0.357178
# 4       LA122989-0007   0.402933  0.477301  0.475050  0.389342  0.513465
# ...                ...       ...       ...       ...       ...       ...
# 57509       FT911-3689  0.560218  0.656592  0.626519  0.471510  0.776798
# 57510       FT911-3690  0.493779  0.422028  0.568813  0.567269  0.621091
# 57511       FT911-3691  0.429324  0.500404  0.293605  0.528717  0.252651
# 57512       FT911-3692  0.437050  0.410097  0.289954  0.600506  0.379818
# 57513       FT911-3693  0.452431  0.497637  0.344397  0.665750  0.362865
#
#               5         6         7         8  ...        90        91  \
# ...

# %%
LDA=pd.read_csv("./LDA_features.csv")
LDA
# Out:
#               0         1         2         3         4         5         6  \
# 0      0.000000  0.000000  0.000000  0.000000  0.328314  0.000000  0.000000
# 1      0.014807  0.019806  0.117594  0.000000  0.075873  0.093464  0.225956
# 2      0.000000  0.000000  0.264080  0.000000  0.000000  0.083615  0.549391
# 3      0.000000  0.047706  0.000000  0.186308  0.000000  0.000000  0.230782
# 4      0.000000  0.000000  0.011776  0.525599  0.000000  0.000000  0.371189
# ...         ...       ...       ...       ...       ...       ...       ...
# 57509  0.000000  0.000000  0.000000  0.125183  0.000000  0.000000  0.000000
# 57510  0.000000  0.089365  0.000000  0.000000  0.000000  0.154981  0.000000
# 57511  0.000000  0.000000  0.000000  0.259584  0.000000  0.000000  0.137142
# 57512  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.051671
# 57513  0.000000  0.017483  0.000000  0.018440  0.018645  0.013202  0.034362
#
# ...

# %%
df_merged = pd.merge(word2vec, LDA, on=['docno'])

# %%
df_merged
# Out:
#                  docno       0_x       1_x       2_x       3_x       4_x  \
# 0       LA122989-0001   0.489329  0.441286  0.600067  0.512963  0.398550
# 1       LA122989-0002   0.501280  0.619327  0.500244  0.467507  0.446816
# 2       LA122989-0005   0.382171  0.541840  0.640981  0.435284  0.244308
# 3       LA122989-0006   0.550603  0.502243  0.392764  0.619229  0.357178
# 4       LA122989-0007   0.402933  0.477301  0.475050  0.389342  0.513465
# ...                ...       ...       ...       ...       ...       ...
# 57509       FT911-3689  0.560218  0.656592  0.626519  0.471510  0.776798
# 57510       FT911-3690  0.493779  0.422028  0.568813  0.567269  0.621091
# 57511       FT911-3691  0.429324  0.500404  0.293605  0.528717  0.252651
# 57512       FT911-3692  0.437050  0.410097  0.289954  0.600506  0.379818
# 57513       FT911-3693  0.452431  0.497637  0.344397  0.665750  0.362865
#
#             5_x       6_x       7_x       8_x  ...      10_y      11_y  \
# ...

# %%
merged_df = pd.merge(word2vec, LDA, on="docno")
merged_df
# Out:
#                  docno       0_x       1_x       2_x       3_x       4_x  \
# 0       LA122989-0001   0.489329  0.441286  0.600067  0.512963  0.398550
# 1       LA122989-0002   0.501280  0.619327  0.500244  0.467507  0.446816
# 2       LA122989-0005   0.382171  0.541840  0.640981  0.435284  0.244308
# 3       LA122989-0006   0.550603  0.502243  0.392764  0.619229  0.357178
# 4       LA122989-0007   0.402933  0.477301  0.475050  0.389342  0.513465
# ...                ...       ...       ...       ...       ...       ...
# 57509       FT911-3689  0.560218  0.656592  0.626519  0.471510  0.776798
# 57510       FT911-3690  0.493779  0.422028  0.568813  0.567269  0.621091
# 57511       FT911-3691  0.429324  0.500404  0.293605  0.528717  0.252651
# 57512       FT911-3692  0.437050  0.410097  0.289954  0.600506  0.379818
# 57513       FT911-3693  0.452431  0.497637  0.344397  0.665750  0.362865
#
#             5_x       6_x       7_x       8_x  ...      10_y      11_y  \
# ...

# %%
merged_df.to_csv('word2vec+LDA.csv',index=False)

# %%
data=pd.read_csv('./word2vec+LDA.csv')
data
# Out:
#                  docno       0_x       1_x       2_x       3_x       4_x  \
# 0       LA122989-0001   0.489329  0.441286  0.600067  0.512963  0.398550
# 1       LA122989-0002   0.501280  0.619327  0.500244  0.467507  0.446816
# 2       LA122989-0005   0.382171  0.541840  0.640981  0.435284  0.244308
# 3       LA122989-0006   0.550603  0.502243  0.392764  0.619229  0.357178
# 4       LA122989-0007   0.402933  0.477301  0.475050  0.389342  0.513465
# ...                ...       ...       ...       ...       ...       ...
# 57509       FT911-3689  0.560218  0.656592  0.626519  0.471510  0.776798
# 57510       FT911-3690  0.493779  0.422028  0.568813  0.567269  0.621091
# 57511       FT911-3691  0.429324  0.500404  0.293605  0.528717  0.252651
# 57512       FT911-3692  0.437050  0.410097  0.289954  0.600506  0.379818
# 57513       FT911-3693  0.452431  0.497637  0.344397  0.665750  0.362865
#
#             5_x       6_x       7_x       8_x  ...      10_y      11_y  \
# ...
