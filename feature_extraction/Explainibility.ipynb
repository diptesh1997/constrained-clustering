# %%
import pandas as pd

# %%
results=pd.read_csv("../result 18.06.2022 20:24:16.csv")
results
# Out:
#               docno         0         1         2         3         4  \
# 0        FT911-3691  0.429324  0.500404  0.293605  0.528717  0.252651
# 1        FT921-1383  0.408350  0.479641  0.347466  0.541619  0.325221
# 2        FT922-2753  0.490877  0.568146  0.317443  0.556734  0.378705
# 3        FT911-1971  0.429033  0.494297  0.354256  0.484559  0.376870
# 4        FT922-1631  0.419866  0.508230  0.358761  0.525312  0.317007
# 5        FT922-2911  0.443027  0.530396  0.307596  0.510491  0.339091
# 6        FT911-2152  0.407166  0.510264  0.327511  0.552767  0.295059
# 7        FT921-1486  0.432198  0.500954  0.318074  0.526999  0.335748
# 8        FT911-3401  0.454917  0.500880  0.324361  0.496681  0.355715
# 9        FT922-2752  0.416324  0.495819  0.372430  0.551430  0.287402
# 10      FT921-12302  0.433438  0.505224  0.292177  0.526135  0.344029
# 11       FT911-1247  0.414194  0.507672  0.408131  0.498205  0.277016
# ...

# %%
groupby=results.groupby(results.columns[-2])[results.columns[-3]].size()
groupby.plot(kind="bar",xlabel="Cluster",ylabel="Number of documents")
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='Number of documents'>
