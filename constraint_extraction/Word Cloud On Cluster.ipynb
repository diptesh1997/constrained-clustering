# %%
import pandas as pd
results=pd.read_csv("./result 18.06.2022 20_24_16.csv",index_col="docno")

results
# Out:
#                         0         1         2         3         4         5  \
# docno
# FT911-3691       0.429324  0.500404  0.293605  0.528717  0.252651  0.511899
# FT921-1383       0.408350  0.479641  0.347466  0.541619  0.325221  0.459653
# FT922-2753       0.490877  0.568146  0.317443  0.556734  0.378705  0.510198
# FT911-1971       0.429033  0.494297  0.354256  0.484559  0.376870  0.486364
# FT922-1631       0.419866  0.508230  0.358761  0.525312  0.317007  0.461842
# FT922-2911       0.443027  0.530396  0.307596  0.510491  0.339091  0.496289
# FT911-2152       0.407166  0.510264  0.327511  0.552767  0.295059  0.487182
# FT921-1486       0.432198  0.500954  0.318074  0.526999  0.335748  0.519879
# FT911-3401       0.454917  0.500880  0.324361  0.496681  0.355715  0.531938
# FT922-2752       0.416324  0.495819  0.372430  0.551430  0.287402  0.532167
# FT921-12302      0.433438  0.505224  0.292177  0.526135  0.344029  0.451441
# ...

# %%
import pandas as pd
results=pd.read_csv("./res1.csv",index_col="docno")

results
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [67], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 results=pd.read_csv("./res1.csv",index_col="docno")
#       4 results
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
groupby=results.groupby(results.columns[-2])[results.columns[-3]].size()
groupby.plot(kind="bar",xlabel="Cluster",ylabel="Number of documents")
# Out:
# <AxesSubplot:xlabel='Cluster', ylabel='Number of documents'>

# %%
import pandas as pd
data=pd.read_csv("./data.csv",index_col="docno")

data
# Out:
#                  doclen                                               text
# docno
#  LA122989-0001       50  the citi compton ask peopl donat book given hi...
#  LA122989-0002      400  sure traffic pace life gener becom hectic luck...
#  LA122989-0005       32  leona helmsley correct said onli littl peopl p...
#  LA122989-0006       87  your editori dec 14 remark upon result studi i...
#  LA122989-0007      431  soviet presid mikhail s gorbachev day away sev...
# ...                 ...                                                ...
# FT911-3689           16  hundr romanian riot polic arm baton shield sto...
# FT911-3690           25  in earli edit financi time april 13 pictur mr ...
# FT911-3691          367  few issu quit controversi govern privatis prog...
# FT911-3692          375  uk stock suffer anoth sharp revers yesterday f...
# FT911-3693         1315  sustain weak royal insur composit insur accomp...
#
# [57514 rows x 2 columns]

# %%
neighbours_tf_idf=data[data.index.isin(results.index)]

# %%
useful_frame=results[['120','121']]
useful_frame
# Out:
#                  120  121
# docno
# FT911-3691       0.0  4.0
# FT921-1383       1.0  0.0
# FT922-2753       1.0  1.0
# FT911-1971       1.0  1.0
# FT922-1631       0.0  3.0
# FT922-2911       0.0  0.0
# FT911-2152       1.0  3.0
# FT921-1486       1.0  0.0
# FT911-3401       1.0  0.0
# FT922-2752       1.0  0.0
# FT921-12302      0.0  4.0
# FT911-1247       1.0  0.0
# FT922-1628       1.0  0.0
# FT921-8558       0.0  1.0
# FT911-1379       1.0  4.0
# FT921-8381       1.0  0.0
# FT922-2749       1.0  1.0
# FT921-7126       1.0  0.0
# FT921-11002      1.0  1.0
# FT921-13167      0.0  1.0
# FT921-8559       1.0  2.0
# FT921-11721      1.0  3.0
# FT921-15872      1.0  0.0
# FT911-3406       1.0  0.0
# FT911-3413       1.0  4.0
# FT921-7038       1.0  0.0
# FT921-300        0.0  0.0
# FT922-4428       1.0  3.0
# FT922-5009       1.0  0.0
# FT921-11533      1.0  4.0
# FT911-3793       0.0  1.0
# FT922-7244       1.0  3.0
# FT921-12526      0.0  1.0
# FT922-2455       1.0  0.0
# ...

# %%
neighbours_tf_idf
# Out:
#                  doclen                                               text
# docno
#  LA103089-0051     1016  zhang xiandi head rural synthet thread factori...
# FT922-2911          579  the quicken pace sale year greec privatis prog...
# FT922-2455          586  globalis rather tarnish concept so made propos...
# FT922-2749          825  it extrem excit time said us lawyer thing quit...
# FT922-2752          611  the develop system stock exchang hamper ideolo...
# FT922-2753          602  just outsid citi yueyang hunan provinc new coa...
# FT922-5704          207  manag russia biggest industri enterpris suppor...
# FT922-5749          240  the focu hungarian privatis turn inward give p...
# FT922-7244          495  the develop european singl market confront ban...
# FT922-6913          760  turkish politician rare discuss issu zeal find...
# FT922-6331          282  last week surpris announc french govern plan s...
# ...

# %%
merged_df = pd.merge(neighbours_tf_idf, useful_frame, on="docno")
merged_df.rename(columns = {'120':'sentiment', '121':'cluster'}, inplace = True)
merged_df
# Out:
#                  doclen                                               text  \
# docno
#  LA103089-0051     1016  zhang xiandi head rural synthet thread factori...
# FT922-2911          579  the quicken pace sale year greec privatis prog...
# FT922-2455          586  globalis rather tarnish concept so made propos...
# FT922-2749          825  it extrem excit time said us lawyer thing quit...
# FT922-2752          611  the develop system stock exchang hamper ideolo...
# FT922-2753          602  just outsid citi yueyang hunan provinc new coa...
# FT922-5704          207  manag russia biggest industri enterpris suppor...
# FT922-5749          240  the focu hungarian privatis turn inward give p...
# FT922-7244          495  the develop european singl market confront ban...
# FT922-6913          760  turkish politician rare discuss issu zeal find...
# FT922-6331          282  last week surpris announc french govern plan s...
# ...

# %%
pos_doc=merged_df[text]['cluster']==1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [44], in <cell line: 1>()
# ----> 1 pos_doc=merged_df[text]['cluster']==1
#
# NameError: name 'text' is not defined

# %%
for i in merged_df['cluster'].unique():
    temp_df=merged_df[merged_df["cluster"]==i]
    print(temp_df.head())
# Out:
#                  doclen                                               text  \
# docno
#  LA103089-0051     1016  zhang xiandi head rural synthet thread factori...
# FT922-2749          825  it extrem excit time said us lawyer thing quit...
# FT922-2753          602  just outsid citi yueyang hunan provinc new coa...
# FT922-5704          207  manag russia biggest industri enterpris suppor...
# FT921-15067         431  whenev french stockbrok gather grumbl lacklust...
#
#                  sentiment  cluster
# docno
#  LA103089-0051         1.0      1.0
# FT922-2749             1.0      1.0
# FT922-2753             1.0      1.0
# FT922-5704             0.0      1.0
# FT921-15067            0.0      1.0
#             doclen                                               text  \
# docno
# FT922-2911     579  the quicken pace sale year greec privatis prog...
# FT922-2455     586  globalis rather tarnish concept so made propos...
# ...

# %%
print(temp_df)
# Out:
#              doclen                                               text  \
# docno
# FT921-3049      634  the transform telecommun across europ past yea...
# FT921-11533     406  the new energi direct put forward ec commiss s...
# FT921-12302     360  a blind spot uk govern larg enlighten telecomm...
# FT921-13071     414  brussel first falter step toward open european...
# FT911-1379      627  when european commun electr supplier clash las...
# FT911-3413      535  the french stateown power util electricit de f...
# FT911-3495      726  east european countri engag heroic changeov ce...
# FT911-3691      367  few issu quit controversi govern privatis prog...
#
#              sentiment  cluster
# docno
# FT921-3049         1.0      4.0
# FT921-11533        1.0      4.0
# FT921-12302        0.0      4.0
# FT921-13071        1.0      4.0
# FT911-1379         1.0      4.0
# FT911-3413         1.0      4.0
# FT911-3495         1.0      4.0
# FT911-3691         0.0      4.0

# %%
worlcloud in temp_df

# %%
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
#top_n=[]
tfidf = TfidfVectorizer(max_features=100, strip_accents='unicode', analyzer='word',  lowercase=True, use_idf=True)
for i in merged_df['cluster'].unique():
    temp_df=merged_df[merged_df["cluster"]==i]
    t = temp_df['text']

    tfs = tfidf.fit_transform(temp_df['text'])

    response = tfidf.transform(temp_df['text'])
    feature_names = tfidf.get_feature_names()
    feature_array = np.array(tfidf.get_feature_names())
    tfidf_sorting = np.argsort(response.toarray()).flatten()[::-1]

    n = 100
    
    top_n = feature_array[tfidf_sorting][:n]
    import numpy as np
    import matplotlib.pyplot as plt
    import pandas as pd
    import sklearn
    from wordcloud import WordCloud, STOPWORDS
    import matplotlib.pyplot as plt
    import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file
    df = top_n
 
    comment_words = ''
    stopwords = set(STOPWORDS)
 
# iterate through the csv file
    for val in df:
     
    # typecaste each val to string
      val = str(val)
 
    # split the value
      tokens = val.split()
     
    # Converts each token into lowercase
      for i in range(len(tokens)):
         tokens[i] = tokens[i].lower()
     
      comment_words += " ".join(tokens)+" "
 
    wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
    plt.figure(figsize = (8, 8), facecolor = None)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.tight_layout(pad = 0)
 
    plt.show()
    print(top_n)
# Out:
# ['invest' 'foreign' 'compani' 'law' 'say' 'year' 'offici' 'take' 'western'
#  'mr' 'the' 'central' 'one' 'even' 'it' 'first' 'set' 'countri' 'manag'
#  'investor' 'privatis' 'make' 'mani' 'sector' 'much' 'busi' 'per' 'cent'
#  'econom' 'also' 'new' 'in' 'last' 'time' 'state' 'main' 'minist'
#  'ownership' 'recent' 'larg' 'use' 'control' 'financi' 'local' 'need'
#  'price' 'becom' 'but' 'problem' 'start' 'enterpris' 'chang' 'servic'
#  'sell' 'way' 'govern' 'exampl' 'good' 'china' 'chines' 'continu'
#  'develop' 'domest' 'howev' 'economi' 'financ' 'effort' 'export' 'high'
#  'million' 'import' 'industri' 'worker' 'work' 'trade' 'thi' 'there'
#  'system' 'still' 'share' 'sale' 'said' 'respons' 'reform' 'provid'
#  'product' 'produc' 'privat' 'power' 'polit' 'plan' 'peopl' 'pension'
#  'ministri' 'would' 'mean' 'may' 'market' 'like' 'almost']
# ['bank' 'greek' 'greec' 'capit' 'the' 'foreign' 'secur' 'alreadi' 'mr'
#  'european' 'system' 'dollar' 'year' 'need' 'privat' 'recent' 'reform'
# ...

# %%
top_n
# Out:
# array(['privatis', 'compani', 'sell', 'foreign', 'programm', 'govern',
#        'economi', 'group', 'the', 'market', 'price', 'larg', 'distort',
#        'way', 'year', 'plan', 'use', 'state', 'help', 'last', 'one',
#        'telecommun', 'import', 'oper', 'util', 'public', 'monopoli',
#        'first', 'say', 'go', 'gener', 'exampl', 'even', 'argu', 'make',
#        'allow', 'need', 'european', 'thi', 'it', 'countri', 'europ',
#        'electr', 'edf', 'energi', 'econom', 'custom', 'eastern', 'east',
#        'domest', 'equip', 'trade', 'direct', 'ec', 'network', 'cost',
#        'consum', 'competit', 'uk', 'commun', 'commiss', 'chang', 'cent',
#        'call', 'but', 'asia', 'us', 'also', 'could', 'system', 'support',
#        'export', 'nation', 'much', 'mr', 'nuclear', 'open', 'mani', 'per',
#        'liberalis', 'plant', 'polici', 'japan', 'would', 'industri', 'in',
#        'power', 'produc', 'rate', 'recent', 'reform', 'germani', 'result',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import sklearn
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
 
# Reads 'Youtube04-Eminem.csv' file
df = top_n
 
comment_words = ''
stopwords = set(STOPWORDS)
 
# iterate through the csv file
for val in df:
     
    # typecaste each val to string
    val = str(val)
 
    # split the value
    tokens = val.split()
     
    # Converts each token into lowercase
    for i in range(len(tokens)):
        tokens[i] = tokens[i].lower()
     
    comment_words += " ".join(tokens)+" "
 
wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stopwords,
                min_font_size = 10).generate(comment_words)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()
